# %% [markdown]
# <a href="https://colab.research.google.com/github/Nihal108-bi/Nihal-AI-ML-Practice-Hub/blob/main/1yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.5/882.5 kB 20.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

import cv2
from google.colab.patches import cv2_imshow
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model=YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 153MB/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
result=model.predict("park_image.jpeg" ,save=True)
result
# Out:
# image 1/1 /content/park_image.jpeg: 448x640 6 persons, 377.0ms
# Speed: 19.7ms preprocess, 377.0ms inference, 39.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
annoted_image=result[0].plot()
cv2_imshow(annoted_image)
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>

# %%
result1=model.predict("park2.jpeg" ,save=True)
annoted_image=result1[0].plot()
cv2_imshow(annoted_image)
# Out:
# image 1/1 /content/park2.jpeg: 448x640 15 persons, 1 bicycle, 1 dog, 207.9ms
# Speed: 3.5ms preprocess, 207.9ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# <PIL.Image.Image image mode=RGB size=272x185>

# %%
#collection of  required data
#annotate a dataset- roboflow
#organizing data from yolo
#create custome data.yaml file
#implementation
#prediction part
#oil based food

# %%
pip install labelImg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 77.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 MB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.5/270.5 kB 17.0 MB/s eta 0:00:00
# ...
#   Created wheel for labelImg: filename=labelImg-1.8.6-py2.py3-none-any.whl size=261520 sha256=1619fe434f9bec7529e9c847617f307f68ac1b0e0fc580ba1e1ad4f1a962c4eb
#   Stored in directory: /root/.cache/pip/wheels/d9/f0/1e/74c509495458cad13a0fda23fe605e643177625cf2b5c17b34
# Successfully built labelImg
# ...

# %%
labelImg

# %%
from google.colab import files
uploaded=files.upload()
