# %% [markdown]
# <a href="https://colab.research.google.com/github/Nihal108-bi/Nihal-AI-ML-Practice-Hub/blob/main/20_nov_and22nov_genai_cloud_computing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.There are few steps to start using hugging face
# 2. First install the hugging face transformer and datasets lib. the lib contain modules for interacting with models for  ml task and datasts from hugging face.
# 3. a ml framework such pytorch will also need to be installed for working ml models and transformers packges

# %%
pip install transformers datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 12.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# ...

# %%
pip install torch torchvision torchaudio

# %% [markdown]
# 1. To navigate the hugging face hub on your notebook you can install huggingface_hub python package
# 2. Then import Hfapi form huggingface_hub . Create an instance of the api, or the tool to communicate with hugging face using python, using the HfApi()

# %%
pip install huggingface_hub

# %%
from huggingface_hub import HfApi
api=HfApi()

# %%
list(api.list_models())
# Out:
# [ModelInfo(id='Qwen/QwQ-32B-Preview', author=None, sha=None, created_at=datetime.datetime(2024, 11, 27, 15, 50, 55, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=2188, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=529, library_name='transformers', tags=['transformers', 'safetensors', 'qwen2', 'text-generation', 'chat', 'conversational', 'en', 'arxiv:2407.10671', 'base_model:Qwen/Qwen2.5-32B-Instruct', 'base_model:finetune:Qwen/Qwen2.5-32B-Instruct', 'license:apache-2.0', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us'], pipeline_tag='text-generation', mask_token=None, card_data=None, widget_data=None, model_index=None, config=None, transformers_info=None, trending_score=529, siblings=None, spaces=None, safetensors=None, security_repo_status=None),
# ...

# %%
api=HfApi()
models=api.list_models(
    sort='downloads',
    direction=-1,
    limit=5
)
modellist=list(models)
print(modellist)
# Out:
# [ModelInfo(id='sentence-transformers/all-mpnet-base-v2', author=None, sha=None, created_at=datetime.datetime(2022, 3, 2, 23, 29, 5, tzinfo=datetime.timezone.utc), last_modified=None, private=False, disabled=None, downloads=339510722, downloads_all_time=None, gated=None, gguf=None, inference=None, likes=910, library_name='sentence-transformers', tags=['sentence-transformers', 'pytorch', 'onnx', 'safetensors', 'openvino', 'mpnet', 'fill-mask', 'feature-extraction', 'sentence-similarity', 'transformers', 'en', 'dataset:s2orc', 'dataset:flax-sentence-embeddings/stackexchange_xml', 'dataset:ms_marco', 'dataset:gooaq', 'dataset:yahoo_answers_topics', 'dataset:code_search_net', 'dataset:search_qa', 'dataset:eli5', 'dataset:snli', 'dataset:multi_nli', 'dataset:wikihow', 'dataset:natural_questions', 'dataset:trivia_qa', 'dataset:embedding-data/sentence-compression', 'dataset:embedding-data/flickr30k-captions', 'dataset:embedding-data/altlex', 'dataset:embedding-data/simple-wiki', 'dataset:emb
# ...

# %% [markdown]
# Huggingface? <<collobaration platform,open-source ML,text,vision , audio tasks,models, datasts, framework
#
# LLM ??<< Understand and generate human like text, massive amount of data,learn pattern in sequence,Encode ,decoder, self attenution

# %% [markdown]
# 1. faster experimentation
# 2. support every step of the process
# 3.smoother adoption

# %% [markdown]
# *Saving a model locally*

# %% [markdown]
# **automodel**

# %%
from transformers import AutoModel

# %%
modelid="distilbert/distilbert-base-uncased-finetuned-sst-2-english"
model=AutoModel.from_pretrained(modelid)

model.save_pretrained(save_directory=f"models/{modelid}")
# Out:
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]

# %% [markdown]
# **dataset**

# %%
from datasets import load_dataset_builder

data_builder=load_dataset_builder("fka/awesome-chatgpt-prompts")
# Out:
# README.md:   0%|          | 0.00/339 [00:00<?, ?B/s]

# %%
data_builder.info.features
# Out:
# {'act': Value(dtype='string', id=None),
#  'prompt': Value(dtype='string', id=None)}

# %%
data_builder.info.description
# Out:
# ''

# %%
data_builder.info.dataset_size
# Out:
# 84093

# %%
from datasets import get_dataset_config_names

configs=get_dataset_config_names('wikipedia')
print(configs)
# Out:
# README.md:   0%|          | 0.00/16.0k [00:00<?, ?B/s]
# wikipedia.py:   0%|          | 0.00/36.7k [00:00<?, ?B/s]
# The repository for wikipedia contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/wikipedia.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# ...

# %%
from datasets import load_dataset
data=load_dataset('imdb')
# Out:
# README.md:   0%|          | 0.00/7.81k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# unsupervised-00000-of-00001.parquet:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# ...
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]

# %%
from datasets import load_dataset
data=load_dataset('imdb',split='train')

# %%
from datasets import load_dataset
data=load_dataset('imdb',split='train')
data.save_to_disk("imdb_dataset")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/25000 [00:00<?, ? examples/s]

# %%
data
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 25000
# })

# %% [markdown]
# *Building pipeline with hugging face*

# %% [markdown]
# 1. there are two ways to use model with transformers package
# 2. one way is with using framework Auto classes
# 3. the other way is with high level helper framework pipeline

# %% [markdown]
# Auto classes:  genral class for using models,tokenizers, configurations,processors,frature extractor,flexible and direct, more control for various task

# %% [markdown]
# Auto model: class for each type task

# %% [markdown]
# Pipeline
# 1. contrains all task-sepcific steps
# 2. best for quicly performing tasks

# %%
from transformers import AutoModelForSequenceClassification
model=AutoModelForSequenceClassification.from_pretrained("distilbert/distilbert-base-uncased-finetuned-sst-2-english")

# %% [markdown]
# **The pipeline module**

# %%
from transformers import pipeline

# %%
my_pipeline=pipeline(task="text-classification")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
my_pipeline=pipeline(model="distilbert/distilbert-base-uncased-finetuned-sst-2-english")
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
my_pipeline=pipeline(task="text-classification",model="distilbert/distilbert-base-uncased-finetuned-sst-2-english")
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %% [markdown]
# pipeline with autoclasses

# %%
from transformers import pipeline,AutoModelForSequenceClassification
model=AutoModelForSequenceClassification.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")
# my_pipeline=pipeline(task="text-classification",model=model)
# Out:
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]

# %% [markdown]
# using the pipeline

# %%
my_pipeline =pipeline(task="text-classification",
                      model="distilbert-base-uncased-finetuned-sst-2-english")
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
input="He this  course is good"
my_pipeline(input)
# Out:
# [{'label': 'POSITIVE', 'score': 0.999853253364563}]

# %%
input="He this  course is bad"
my_pipeline(input)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9998131394386292}]

# %%
input='''Very good quality product, little heating is observed but no effect on result. Value for money, light weight and efficient'''
my_pipeline(input)
# Out:
# [{'label': 'POSITIVE', 'score': 0.6831899881362915}]

# %% [markdown]
# **Tokenization: **
# 1. converting a sequence into a smaller part
# 2. numerical form
# 3. components:
#  -normalization
# :- transformation and cleaning
# :- pre-tokenization: splitting in smaller part
# :- tokenization in model

# %% [markdown]
# Normalization:
# 1. cleaning text
# 2. lowering
# 3. pnchuation
# 4. ramoving whitespaces

# %% [markdown]
# we can use Autotokenizer class and .from_pretrained()
# 1. we have access to the normalize methods used to tokenise by calling tokenizer.backend_tokenizer.normalizer_str()

# %%
from transformers import GPT2Tokenizer

input=" HELLO ,,|| how are you?"

gpt_tokenizer=GPT2Tokenizer.from_pretrained("gpt2")
gpt_tokens=gpt_tokenizer.tokenize(input)
print(gpt_tokens)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# ['ĠHELL', 'O', 'Ġ,', ',', '||', 'Ġhow', 'Ġare', 'Ġyou', '?']

# %%
from transformers import GPT2Tokenizer,AutoTokenizer

input=" HELLO ,,|| how are you?"

tokenizer=AutoTokenizer.from_pretrained("distilbert-base-uncased")
tokenizer.backend_tokenizer.normalizer.normalize_str(input)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# ' hello ,,|| how are you?'

# %% [markdown]
# **Text Classification**

# %% [markdown]
# # sentiment-analysis

# %%
from transformers import pipeline
classifier=pipeline(task="sentiment-analysis")
print(classifier("I've been waiting for a huggingface course my whole life."))
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'label': 'POSITIVE', 'score': 0.9598048329353333}]

# %% [markdown]
# **Grammatical correctness**

# %%
from transformers import pipeline
classifier=pipeline(task="text-classification",
                    model="abdulmatinomotoso/Grammar_Checkerr")
print(classifier("my name is mrnj"))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     405     try:
# --> 406         response.raise_for_status()
#     407     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/abdulmatinomotoso/Grammar_Checkerr/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# ...

# %%
from transformers import pipeline
classifier=pipeline(task="text-classification",
                    model="cross-encoder/qnli-electra-base")
print(classifier("What is the capital of france? ""paris is the capital of france."))
# Out:
# config.json:   0%|          | 0.00/771 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/268 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'label': 'LABEL_0', 'score': 0.9982080459594727}]

# %%
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'label': 'LABEL_0', 'score': 0.0005536185926757753}]

# %%
# Out:
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# {'sequence': 'This is a course about the transformers library', 'labels': ['education', 'business', 'politics'], 'scores': [0.9192401170730591, 0.060778871178627014, 0.019981026649475098]}
# education
# 0.9192401170730591

# %%
from transformers import pipeline

model = "sshleifer/distilbart-cnn-12-6"
summarizer = pipeline(task="summarization", model=model)
text="""

Animals are multicellular, eukaryotic organisms in the biological kingdom Animalia
 (/ˌænɪˈmeɪliə/[4]). With few exceptions,
  animals consume organic material, breathe oxygen,
  have myocytes and are able to move, can reproduce sexually,
   and grow from a hollow sphere of cells, the blastula,
   during embryonic development. Animals form a clade, meaning
    that they arose from a single common ancestor. Over 1.5 million
    living animal species have been described, of which around 1.05
    million are insects, over 85,000 are molluscs, and around 65,000 are
     vertebrates. It has been estimated there are as many as 7.77 million
     animal species on Earth. Animal body lengths range from 8.5 μm (0.00033 in)
      to 33.6 m (110 ft). They have complex ecologies and interactions
       with each other and their environments, forming intricate food
       webs. The scientific study of animals is known as zoology, and
       the study of animal behaviour is known as ethology.




"""
summary_text=summarizer(text)

print(summary_text[0]["summary_text"])
# Out:
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
#  Animals are multicellular, eukaryotic organisms in the biological kingdom Animalia. They consume organic material, breathe oxygen, have myocytes and are able to move, reproduce sexually, and grow from a hollow sphere of cells, the blastula, during embryonic development. Animals form a clade, meaning they arose from a single common ancestor .

# %% [markdown]
# **Images**

# %% [markdown]
# 1. images are made of pixels
# 2. pixels contain info about color (grey scale /rgb)
# 3. nuber of pixels from 1 to infinity
# 4. more pixels=higher resolution

# %% [markdown]
# Common pre-processing steps
# 1. cropping
# 2.resizing

# %%
#transforming images

from transformers import image_transforms

from PIL import Image
original_image=Image.open("/content/img.png")

# %%
original_image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=472x320>

# %%
import numpy as np
image_array=np.array(original_image)
print(image_array)
# Out:
# [[[ 50  34  18]
#   [ 52  36  20]
#   [ 53  38  19]
#   ...
#   [ 23  13   5]
#   [ 25  15   5]
#   [ 24  14   5]]
#
#  [[ 52  35  20]
#   [ 52  36  20]
#   [ 52  36  20]
#   ...
#   [ 24  14   5]
#   [ 24  14   4]
#   [ 26  16   7]]
#
#  [[ 52  36  19]
#   [ 50  35  18]
#   [ 51  35  21]
#   ...
#   [ 27  17   8]
#   [ 24  14   4]
#   [ 26  16   5]]
#
#  ...
#
#  [[ 32  15   3]
#   [ 31  15   3]
#   [ 32  16   3]
#   ...
#   [ 39  19   8]
#   [ 41  25   9]
#   [ 64  36  14]]
#
#  [[ 33  16   3]
#   [ 32  16   4]
#   [ 32  16   2]
#   ...
#   [ 39  19   8]
#   [ 40  24   8]
#   [ 65  38  16]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
cropped_image=image_transforms.center_crop(
    image_array,
    size=(100,100)
)

# %%
print(cropped_image)
# Out:
# [[[ 90  66  28]
#   [ 75  56  22]
#   [ 64  47  22]
#   ...
#   [216 116  44]
#   [214 127  56]
#   [225 134  65]]
#
#  [[ 83  63  27]
#   [ 71  52  25]
#   [ 61  45  21]
#   ...
#   [223 133  57]
#   [227 144  66]
#   [226 134  61]]
#
#  [[ 80  59  27]
#   [ 70  51  26]
#   [ 61  45  22]
#   ...
#   [227 133  60]
#   [226 132  61]
#   [231 137  64]]
#
#  ...
#
#  [[219 194  78]
#   [218 193  75]
#   [213 189  75]
#   ...
#   [190  93  33]
#   [185  88  31]
#   [171  79  23]]
#
#  [[218 197  82]
#   [218 192  79]
#   [206 187  75]
#   ...
#   [187  90  30]
#   [190  91  31]
#   [181  83  23]]
#
#  [[216 195  79]
#   [210 188  77]
#   [179 156  60]
#   ...
#   [194  94  30]
#   [199  99  29]
#   [190  85  26]]]

# %%
image_transforms.center_crop(
    image=np.array(original_image),
    size=(100,100)
)
# Out:
# array([[[ 90,  66,  28],
#         [ 75,  56,  22],
#         [ 64,  47,  22],
#         ...,
#         [216, 116,  44],
#         [214, 127,  56],
#         [225, 134,  65]],
#
#        [[ 83,  63,  27],
#         [ 71,  52,  25],
#         [ 61,  45,  21],
#         ...,
#         [223, 133,  57],
#         [227, 144,  66],
#         [226, 134,  61]],
#
#        [[ 80,  59,  27],
#         [ 70,  51,  26],
#         [ 61,  45,  22],
#         ...,
#         [227, 133,  60],
#         [226, 132,  61],
#         [231, 137,  64]],
#
#        ...,
#
#        [[219, 194,  78],
#         [218, 193,  75],
#         [213, 189,  75],
#         ...,
#         [190,  93,  33],
#         [185,  88,  31],
#         [171,  79,  23]],
#
#        [[218, 197,  82],
#         [218, 192,  79],
#         [206, 187,  75],
#         ...,
#         [187,  90,  30],
#         [190,  91,  31],
#         [181,  83,  23]],
#
#        [[216, 195,  79],
#         [210, 188,  77],
#         [179, 156,  60],
# ...

# %% [markdown]
# Image classification
# 1. it is process of assigning labels to an image

# %%
from transformers import pipeline
classifier=pipeline(task="image-classification",
                    model="google/vit-base-patch16-224")
# Out:
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
result=classifier(images="/content/images (2).jpg")

# %%
result
# Out:
# [{'label': 'Siamese cat, Siamese', 'score': 0.9115808010101318},
#  {'label': 'Egyptian cat', 'score': 0.034516338258981705},
#  {'label': 'Persian cat', 'score': 0.023104168474674225},
#  {'label': 'lynx, catamount', 'score': 0.009811179712414742},
#  {'label': 'tabby, tabby cat', 'score': 0.003945618402212858}]

# %% [markdown]
# **Document Q &A **

# %%
from transformers import pipeline
classifier=pipeline(task="document-question-answering",
                    model="naver-clova-ix/donut-base-finetuned-docvqa")
# Out:
# config.json:   0%|          | 0.00/4.74k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/803M [00:00<?, ?B/s]
# Config of the encoder: <class 'transformers.models.donut.modeling_donut_swin.DonutSwinModel'> is overwritten by shared encoder config: DonutSwinConfig {
#   "attention_probs_dropout_prob": 0.0,
#   "depths": [
#     2,
#     2,
#     14,
#     2
#   ],
#   "drop_path_rate": 0.1,
#   "embed_dim": 128,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 1024,
#   "image_size": [
#     2560,
#     1920
#   ],
#   "initializer_range": 0.02,
#   "layer_norm_eps": 1e-05,
#   "mlp_ratio": 4.0,
#   "model_type": "donut-swin",
#   "num_channels": 3,
#   "num_heads": [
#     4,
#     8,
#     16,
#     32
#   ],
#   "num_layers": 4,
#   "patch_size": 4,
#   "path_norm": true,
#   "qkv_bias": true,
#   "transformers_version": "4.46.2",
#   "use_absolute_embeddings": false,
#   "window_size": 10
# }
#
# ...

# %%
document_image="/content/shot.png"
question_text="what is this shot about?"
result=classifier(image=document_image,question=question_text)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1375: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# MBartModel is using MBartSdpaAttention, but `torch.nn.functional.scaled_dot_product_attention` does not support `output_attentions=True` or `layer_head_mask` not None. Falling back to the manual attention implementation, but specifying the manual implementation will be required from Transformers version v5.0.0 onwards. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.

# %%
result
# Out:
# [{'answer': 'translate full page'}]
